# %% [markdown]
# # Validation of jupyter inner images with nbdev
# - show_tags: true
# - toc: true
# - branch: master
# - badges: false
# - comments: true
# - categories: [blog]

# %% [markdown]
# ![image.png](attachment:image.png)
